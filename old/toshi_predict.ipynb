# %%
import numpy as np
import os
import glob
from JTA_FFT import JTA_FFT
import cv2

# %%
HOME_DIR = "C:/Datasets_FemCleaned/Toshi/Toshi_Organized/"
pats = ["Patient_10_Lt", "Patient_11_Lt"]
for pat in pats:
    PAT_DIR = HOME_DIR + pat + "/Session_1/"

    
    for mvt_id in os.listdir(PAT_DIR):
        MVT_DIR = PAT_DIR + "/" + mvt_id

        centroid_library = np.load(MVT_DIR + "/FFT/dc_fem.npy")
        mag_library = np.load(MVT_DIR + "/FFT/mag_fem.npy")
        angle_library = np.load(MVT_DIR + "/FFT/lib-angle_fem.npy")
        NFD_library = np.load(MVT_DIR + "/FFT/surface_fem.npy")
        rot_indices = np.load(MVT_DIR + "/FFT/rot_indices.npy")

        IMG_DIR = MVT_DIR + "/1024/fem/"

        num = len(os.listdir(IMG_DIR))
        jts_file = np.empty([num,6])

        for idx, img_id in enumerate(os.listdir(IMG_DIR)):
            img = cv2.imread(IMG_DIR + "/" + img_id,cv2.IMREAD_GRAYSCALE)
            cal = MVT_DIR + "/cal1024.txt"
            FEM_FFT = JTA_FFT(cal)

            x_input, y_input = FEM_FFT.create_contour(img)

            centroid_instance, mag_instance, angle_instance, NFD_instance = FEM_FFT.get_NFD(x_input,y_input)

            x, y, z, zr, xr, yr = FEM_FFT.estimate_pose(
                                                    rot_indices,
                                                    centroid_library, mag_library, angle_library, NFD_library,
                                                    centroid_instance, mag_instance, angle_instance, NFD_instance)

            jts_file[idx,:] = [x,y,z,zr,xr,yr]



        header = ["x_tran", "y_tran", "z_tran", "z_rot", "x_rot", "y_rot"]

        np.savetxt(MVT_DIR + "/fem_fft.jts", jts_file, delimiter=',', header = "x_trans, y_trans, z_trans, z_rot, x_rot, y_rot", fmt = "   %.2f")
# Out:
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][875]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][870]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][876]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][869]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][884]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][913]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][898]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][885]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][873]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][882]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][867]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][854]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][850]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][838]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][829]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][831]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][843]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][857]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][906]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][595]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][616]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][638]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][593]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][802]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][776]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][776]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][772]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][768]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][768]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][758]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][755]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][753]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][756]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][771]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][803]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][801]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][749]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][781]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][785]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][769]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][756]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][763]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][790]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][820]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][666]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][666]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][687]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][655]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][698]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][698]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][685]=x[0][0]
#   (i, m, i)))

# %%
HOME_DIR = "C:/Datasets_FemCleaned/Toshi/Toshi_Organized/"
pats = ["Patient_10_Lt", "Patient_11_Lt"]
for pat in pats:
    PAT_DIR = HOME_DIR + pat + "/Session_1/"

    
    for mvt_id in os.listdir(PAT_DIR):
        MVT_DIR = PAT_DIR + "/" + mvt_id

        centroid_library = np.load(MVT_DIR + "/FFT/dc_tib.npy")
        mag_library = np.load(MVT_DIR + "/FFT/mag_tib.npy")
        angle_library = np.load(MVT_DIR + "/FFT/lib-angle_tib.npy")
        NFD_library = np.load(MVT_DIR + "/FFT/surface_tib.npy")
        rot_indices = np.load(MVT_DIR + "/FFT/rot_indices.npy")

        IMG_DIR = MVT_DIR + "/1024/tib/"

        num = len(os.listdir(IMG_DIR))
        jts_file = np.empty([num,6])

        for idx, img_id in enumerate(os.listdir(IMG_DIR)):
            img = cv2.imread(IMG_DIR + "/" + img_id,cv2.IMREAD_GRAYSCALE)
            cal = MVT_DIR + "/cal1024.txt"
            tib_FFT = JTA_FFT(cal)

            x_input, y_input = tib_FFT.create_contour(img)

            centroid_instance, mag_instance, angle_instance, NFD_instance = tib_FFT.get_NFD(x_input,y_input)

            x, y, z, zr, xr, yr = tib_FFT.estimate_pose(
                                                    rot_indices,
                                                    centroid_library, mag_library, angle_library, NFD_library,
                                                    centroid_instance, mag_instance, angle_instance, NFD_instance)

            jts_file[idx,:] = [x,y,z,zr,xr,yr]



        header = ["x_tran", "y_tran", "z_tran", "z_rot", "x_rot", "y_rot"]

        np.savetxt(MVT_DIR + "/tib_fft.jts", jts_file, delimiter=',', header = "x_trans, y_trans, z_trans, z_rot, x_rot, y_rot", fmt = "   %.2f")
# Out:
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][691]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][693]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][696]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][702]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][707]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][700]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][699]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][699]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][688]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][685]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][683]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][686]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][689]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][473]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][510]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][502]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][502]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][479]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][590]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][497]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][511]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][515]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][520]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][526]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][530]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][530]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][531]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][536]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][548]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][537]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][500]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][504]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][527]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][528]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][529]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][519]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][509]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][517]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][545]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][545]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][438]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][491]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][467]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][472]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][469]=x[0][0]
#   (i, m, i)))
