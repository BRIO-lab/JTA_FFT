# %%
import numpy as np
import os
import glob
from JTA_FFT import JTA_FFT
import cv2

# %%
HOME_DIR  = "C:/Datasets_FemCleaned/Florent/Florent_Organized/Patient_TKA1 (F4T4 R)/Session_1/"
dirlist = [filename for filename in os.listdir(HOME_DIR) if os.path.isdir(os.path.join(HOME_DIR,filename))]
lib_dc = np.load(HOME_DIR + "/dc_tib.npy")
lib_angle = np.load(HOME_DIR + "/lib-angle_tib.npy")
lib_mag = np.load(HOME_DIR + "/mag_tib.npy")
lib_surface = np.load(HOME_DIR + "/surface_tib.npy")
tib_surface = np.load(HOME_DIR + "surface_tib.npy")
rot_indices = np.load(HOME_DIR + "/rot_indices.npy")

for mvt_id in dirlist:
    MVT_DIR = HOME_DIR + "/" + mvt_id 
    IMG_DIR = MVT_DIR + "/labels/NN output/tib/" 
    num = len(os.listdir(IMG_DIR))
    jts_file = np.empty([num,6])
    for idx, img_id in enumerate(os.listdir(IMG_DIR)):
        img = cv2.imread(IMG_DIR + "/" + img_id,cv2.IMREAD_GRAYSCALE)
        cal = MVT_DIR + "/calibration.txt"
        tib_FFT = JTA_FFT(cal)
        
        x_input, y_input = tib_FFT.create_contour(img)
        dc, mag, angle, surface = tib_FFT.get_NFD(x_input, y_input)

        xt, yt, zt, zr, xr, yr = tib_FFT.estimate_pose(rot_indices, lib_dc, lib_mag, lib_angle, lib_surface, dc, mag, angle, surface)

        jts_file[idx,:] = [xt,yt,zt,zr,xr,yr]

    
    header = ["x_tran", "y_tran", "z_tran", "z_rot", "x_rot", "y_rot"]

    np.savetxt(MVT_DIR + "/tib_fft.jts", jts_file, delimiter=',', header = "x_trans, y_trans, z_trans, z_rot, x_rot, y_rot", fmt = "   %.2f")
# Out:
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][939]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][941]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][947]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][953]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][959]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][978]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][985]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][979]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][991]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][993]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][989]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][997]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][987]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][988]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][990]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][982]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][974]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][972]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][973]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][966]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][956]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][956]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][954]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][949]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][942]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][936]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][928]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][920]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][906]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][900]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][893]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][884]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][877]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][867]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][859]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][837]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][821]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][830]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][817]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][797]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][810]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][792]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][791]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][779]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][782]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][794]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][783]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][790]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][798]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][806]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][823]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][827]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][862]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][836]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][863]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][839]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][839]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][845]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][853]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][859]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][866]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][873]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][875]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][879]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][907]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][918]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][892]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][880]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][872]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][861]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][849]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][849]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][851]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][848]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][916]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][897]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][874]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][870]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][931]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][931]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][829]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][820]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][809]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][831]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][785]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][784]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][776]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][781]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][769]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][767]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][772]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][766]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][770]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][785]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][773]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][773]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][787]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][800]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][804]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][802]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][786]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][807]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][835]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][826]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][852]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][840]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][840]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][827]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][843]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][865]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][850]=x[0][0]
#   (i, m, i)))

# %%
HOME_DIR  = "C:/Datasets_FemCleaned/Florent/Florent_Organized/Patient_TKA1 (F4T4 R)/Session_1/"
dirlist = [filename for filename in os.listdir(HOME_DIR) if os.path.isdir(os.path.join(HOME_DIR,filename))]
lib_dc = np.load(HOME_DIR + "/dc_fem.npy")
lib_angle = np.load(HOME_DIR + "/lib-angle_fem.npy")
lib_mag = np.load(HOME_DIR + "/mag_fem.npy")
lib_surface = np.load(HOME_DIR + "/surface_fem.npy")
fem_surface = np.load(HOME_DIR + "surface_fem.npy")
rot_indices = np.load(HOME_DIR + "/rot_indices.npy")

for mvt_id in dirlist:
    MVT_DIR = HOME_DIR + "/" + mvt_id 
    IMG_DIR = MVT_DIR + "/labels/NN output/fem/" 
    num = len(os.listdir(IMG_DIR))
    jts_file = np.empty([num,6])
    for idx, img_id in enumerate(os.listdir(IMG_DIR)):
        img = cv2.imread(IMG_DIR + "/" + img_id,cv2.IMREAD_GRAYSCALE)
        cal = MVT_DIR + "/calibration.txt"
        fem_FFT = JTA_FFT(cal)
        
        x_input, y_input = fem_FFT.create_contour(img)
        dc, mag, angle, surface = fem_FFT.get_NFD(x_input, y_input)

        xt, yt, zt, zr, xr, yr = fem_FFT.estimate_pose(rot_indices, lib_dc, lib_mag, lib_angle, lib_surface, dc, mag, angle, surface)

        jts_file[idx,:] = [xt,yt,zt,zr,xr,yr]

    
    header = ["x_tran", "y_tran", "z_tran", "z_rot", "x_rot", "y_rot"]

    np.savetxt(MVT_DIR + "/fem_fft.jts", jts_file, delimiter=',', header = "x_trans, y_trans, z_trans, z_rot, x_rot, y_rot", fmt = "   %.2f")
# Out:
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1051]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1049]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1050]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][1050]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1048]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1045]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1046]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1047]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1044]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1043]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1041]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1042]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1034]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1033]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1040]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1066]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1102]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1109]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1106]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1110]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1108]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1116]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1117]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1123]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1115]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1114]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1126]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1118]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1150]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1113]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1100]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1112]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1148]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1129]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1130]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1124]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1122]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[1][1122]=x[1][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1111]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1085]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1083]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1077]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1074]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1065]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1052]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1016]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1007]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1000]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1004]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1005]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1010]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1009]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1011]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1014]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1020]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1022]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1021]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1017]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1012]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1013]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1018]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1026]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1024]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1023]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1032]=x[0][0]
#   (i, m, i)))
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\scipy\interpolate\_fitpack_impl.py:227: RuntimeWarning: Setting x[0][1027]=x[0][0]
#   (i, m, i)))
