# %%
from JTA_FFT_try import JTA_FFT
import os
import glob
import numpy as np
import gc
def main():

    
    
    HOME_DIR = "C:/Datasets_FemCleaned/"
    study_list = ["GMK"]
    
    for study in study_list:
        study_dir = HOME_DIR + "/" + study
        NFD_DIR = study_dir + "/" + "NFD Library/lib/"
        
        if study != "Lima":
            DATA_DIR =  study_dir + "/" + study +  "_Organized"
        else:
            DATA_DIR =  study_dir + "/" + study +  "_Organized_Updated"
            
        
        for pat_id in [x for x in os.listdir(DATA_DIR) if os.path.isdir(DATA_DIR + "/" + x)]:
            PAT_DIR = DATA_DIR + "/" + pat_id
            for sess_id in [x for x in os.listdir(PAT_DIR) if os.path.isdir(PAT_DIR + "/" + x)]:
                SESS_DIR = PAT_DIR + "/" + sess_id
                for mvt_id in [x for x in os.listdir(SESS_DIR) if (os.path.isdir(SESS_DIR + "/" + x))]:
                    MVT_DIR = SESS_DIR + "/" + mvt_id
                    cal = MVT_DIR + "/cal1024.txt"
                    if not os.path.exists(cal):
                        cal = MVT_DIR + "/1024/cal1024.txt"
                        if not os.path.exists(cal):
                            cal = MVT_DIR + "/calibration.txt"
                            if not os.path.exists(cal):
                                raise Exception ("No calibration file found: ",cal)
                    STL_LIST = glob.glob1(MVT_DIR, "*.stl")
                    for STL in STL_LIST:
                        stl_name = os.path.splitext(STL)[0]
                        NFD = JTA_FFT(cal)
                        NFD.create_nfd_library(MVT_DIR +"/" +  STL)
                        stl_name = os.path.splitext(STL)[0]
                        NFD.print_library(0,1,125)

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ajensen123\AppData\Local\Temp\ipykernel_34004\451043146.py in <module>
# ----> 1 main()
#
# C:\Users\ajensen123\AppData\Local\Temp\ipykernel_34004\1468404074.py in main()
#      40                         NFD.create_nfd_library(MVT_DIR +"/" +  STL)
#      41                         stl_name = os.path.splitext(STL)[0]
# ---> 42                         NFD.print_library(0,1,125)
#
# c:\Users\ajensen123\Desktop\JTML\JTA_FFT\JTA_FFT_try.py in print_library(self, norm_coeff, clock_arm_length, scale)
#     879                 ax.plot(x_cent, y_cent, marker = "x", color = "black", markersize = 10)
#     880                 ax.set_xlabel("X-rotation", size = 35)
# --> 881                 plt.xticks(fontsize = 25)
#     882                 ax.set_ylabel("Y-rotation", size = 35)
#     883                 plt.yticks(fontsize = 25)
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1781
#    1782     if ticks is None:
# -> 1783         locs = ax.get_xticks()
#    1784         if labels is not None:
#    1785             raise TypeError("xticks(): Parameter 'labels' can't be set "
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      73
#      74         def wrapper(self, *args, **kwargs):
# ---> 75             return get_method(self)(*args, **kwargs)
#      76
#      77         wrapper.__module__ = owner.__module__
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axis.py in get_ticklocs(self, minor)
#    1297     def get_ticklocs(self, *, minor=False):
#    1298         """Return this Axis' tick locations in data coordinates."""
# -> 1299         return self.get_minorticklocs() if minor else self.get_majorticklocs()
#    1300
#    1301     def get_ticks_direction(self, minor=False):
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1275     def get_majorticklocs(self):
#    1276         """Return this Axis' major tick locations in data coordinates."""
# -> 1277         return self.major.locator()
#    1278
#    1279     def get_minorticklocs(self):
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2111
#    2112     def __call__(self):
# -> 2113         vmin, vmax = self.axis.get_view_interval()
#    2114         return self.tick_values(vmin, vmax)
#    2115
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axis.py in getter(self)
#    1985     def getter(self):
#    1986         # docstring inherited.
# -> 1987         return getattr(getattr(self.axes, lim_name), attr_name)
#    1988
#    1989     def setter(self, vmin, vmax, ignore=False):
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axes\_base.py in viewLim(self)
#     779     @property
#     780     def viewLim(self):
# --> 781         self._unstale_viewLim()
#     782         return self._viewLim
#     783
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axes\_base.py in _unstale_viewLim(self)
#     775                     ax._stale_viewlims[name] = False
#     776             self.autoscale_view(**{f"scale{name}": scale
# --> 777                                    for name, scale in need_scale.items()})
#     778
#     779     @property
#
# C:\Users\ajensen123\.conda\envs\FFT\lib\site-packages\matplotlib\axes\_base.py in autoscale_view(self, tight, scalex, scaley)
#    2851                 x_stickies = np.sort(np.concatenate([
#    2852                     artist.sticky_edges.x
# -> 2853                     for ax in self._shared_axes["x"].get_siblings(self)
#    2854                     if hasattr(ax, "_children")
#    2855                     for artist in ax.get_children()]))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
